# %% [markdown]
# # <center><font size= '7' color='red'>𝓢𝓽𝓪𝓻𝓽𝓾𝓹𝓼 𝓟𝓻𝓸𝒇𝓲𝓽 𝓟𝓻𝓮𝓭𝓲𝓬𝓽𝓲𝓸𝓷 𝓤𝓼𝓲𝓷𝓰</font></center><center><font size= '7' color='SlateBlue'>𝓛𝓲𝓷𝓮𝓪𝓻 𝓡𝓮𝓰𝓻𝓮𝓼𝓼𝓲𝓸𝓷 𝓜𝓸𝓭𝓮𝓵</font></center>

# %% [markdown]
# ![machine learning.jpeg](attachment:d1f08df7-d6ef-4d69-9cf8-80e1d156c557.jpeg)

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Importing Libraries</font>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Reading and exploring the dataset</font>

# %%
data = pd.read_csv('50_Startups.csv')

# %%
# Print first 5 rows of dataset
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Print first 10 rows of dataset
data.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
# Print last 5 rows of dataset
data.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# Print last 10 rows of dataset
data.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# Checking the number of rows and columns in the dataset
data.shape # (rows, columns)
# Out:
# (50, 5)

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Handling Missing Values</font>

# %%
if data.isnull().values.any():
    print('Yes, there are null values.')
    print(data.isnull().sum()) # or print(data.isna().sum()) 
else:
    print('No, there aren\'t null values.')
# Out:
# No, there aren't null values.

# %%
# Cleaning
# Remove rows with any missing values
#data = data.dropna()

# Remove columns with any missing values
#data = data.dropna(axis=1)

# %%
# data.isnull().values.any()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Encoding Categorical Values</font>

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the categorical variable
data['State_Encoded'] = label_encoder.fit_transform(data['State'])

# Convert encoded values to int
data['State_Encoded'] = data['State_Encoded'].astype(int)
data.drop(['State'], axis=1, inplace=True)

data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_Encoded
# 0  165349.20       136897.80        471784.10  192261.83              2
# 1  162597.70       151377.59        443898.53  191792.06              0
# 2  153441.51       101145.55        407934.54  191050.39              1
# 3  144372.41       118671.85        383199.62  182901.99              2
# 4  142107.34        91391.77        366168.42  166187.94              1

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Multivariate Quantitative EDA (Correlation)</font>
# ## <font color='SaddleBrown'>1- Positive Correlation</font>
# ## <font color='SaddleBrown'>2- Negative Correlation</font>

# %% [markdown]
# ![Corr.png](attachment:49cdd552-92a0-44f7-94e0-33ddd82344a5.png)

# %%
# EDA => Exploratory Data Analysis
# Understanding the correlation between various features in the dataset
# Select only the numeric columns
numeric_df = data.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit  \
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000
# State_Encoded     0.104685        0.011847         0.077670  0.101796
#
#                  State_Encoded
# R&D Spend             0.104685
# Administration        0.011847
# Marketing Spend       0.077670
# Profit                0.101796
# State_Encoded         1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, linewidth=0.5, fmt = '.1f', cmap='plasma')
plt.title('Correlation Heatmap between various features in the dataset')
plt.show()

# "annot=True" => ensures that the correlation values appear on the heatmap.
# "cmap='plasma'" => specifies the color palette. In this case, we’ve chosen 'plasma'.
# "linewidths=0.5" => determines the width of the lines that will divide each cell.

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Correlation between <b>R&D Spend</b> and <b>R&D Spend</b> = (1)</font>

# %%
plt.scatter(data['R&D Spend'], data['R&D Spend'], label='Data')
plt.plot(data['R&D Spend'], data['R&D Spend'], color='red', label='Line')
plt.xlabel('R&D Spend')
plt.ylabel('R&D Spend')
plt.title('R&D Spend vs. R&D Spend')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Correlation between <b>R&D Spend</b> and <b>Administration</b> = (0.24)</font>

# %%
plt.scatter(data['R&D Spend'], data['Administration'])
# plt.plot(data['R&D Spend'], data['Administration'], color='red', label='Line')
plt.xlabel('R&D Spend')
plt.ylabel('Administration')
plt.title('R&D Spend vs. Administration')
plt.grid(True)
plt.show()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Correlation between <b>R&D Spend</b> and <b>Marketing Spend</b> = (0.72)</font>

# %%
plt.scatter(data['R&D Spend'], data['Marketing Spend'])
# plt.plot(data['R&D Spend'], data['Marketing Spend'], color='red', label='Line')
plt.xlabel('R&D Spend')
plt.ylabel('Marketing Spend')
plt.title('R&D Spend vs. Marketing Spend')
plt.grid(True)
plt.show()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Correlation between <b>R&D Spend</b> and <b>Profit</b> = (0.97)</font>

# %%
plt.scatter(data['R&D Spend'], data['Profit'])
# plt.plot(data['R&D Spend'], data['Profit'], color='red', label='Line')
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.title('R&D Spend vs. Profit')
plt.grid(True)
plt.show()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Correlation between <b>R&D Spend</b> and <b>State_Encoded</b> = (0.1)</font>

# %%
plt.scatter(data['R&D Spend'], data['State_Encoded'])
# plt.plot(data['R&D Spend'], data['State_Encoded'], color='red', label='Line')
plt.xlabel('R&D Spend')
plt.ylabel('State_Encoded')
plt.title('R&D Spend vs. State_Encoded')
plt.grid(True)
plt.show()

# %%
outliers = ['Profit']
plt.rcParams['figure.figsize'] = [4, 4]
sns.boxplot(data=data[outliers], orient='v', palette='husl', width=0.7)

plt.title('Outliers Variable Distribution')
plt.ylabel('Profit Range')
plt.show()

# %%
sns.histplot(data['Profit'], bins=5, kde=True)
plt.show()

# %%
sns.pairplot(data)

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Splitting the data and target</font>

# %%
# X Data
X = data.drop(['Profit'], axis=1, inplace=False)
print('X Data is : \n' , X.head())
print()
print('X shape is : ' , X.shape)
print('-' * 100)
print()

# y Data
y = data['Profit']
print('y Data is : \n' , y.head())
print('y shape is : ' , y.shape)

#X = X.to_numpy()
#y = y.to_numpy()
#y = y.reshape(-1, 1)
# Out:
# X Data is :
#     R&D Spend  Administration  Marketing Spend  State_Encoded
# 0  165349.20       136897.80        471784.10              2
# 1  162597.70       151377.59        443898.53              0
# 2  153441.51       101145.55        407934.54              1
# 3  144372.41       118671.85        383199.62              2
# 4  142107.34        91391.77        366168.42              1
#
# X shape is :  (50, 4)
# ----------------------------------------------------------------------------------------------------
#
# y Data is :
#  0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64
# y shape is :  (50,)

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Data Partitioning / Train Test Split</font>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle =True)

# Splitted Data
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (35, 4)
# X_test shape is  (15, 4)
# y_train shape is  (35,)
# y_test shape is  (15,)

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Data Scaling / Feature Scaling</font>
#
# ### <font color='SaddleBrown'>- <b>MinMaxScaler</b> is a preprocessing technique provided by Scikit-Learn that scales and transforms features in a dataset to a specified range, typically between 0 and 1.</font>
# ### <font color='SaddleBrown'>- This scaling is particularly useful for machine learning algorithms that require features to have similar ranges to prevent certain features from dominating the learning process.</font>
# ### <font color='SaddleBrown'>- <b>MinMaxScaler</b> can help improve the performance and convergence of models.</font>

# %% [markdown]
# ![min_max_scaling.jpg](attachment:fa7b15c0-95e5-4fa6-a85f-f5e753c78620.jpg)

# %%
# MinMaxScaler for Data

scaler = MinMaxScaler()

# Fit the scaler on the training data
scaler.fit(X_train)

# Transform the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test) # Generalizing what you learned in "Training Data" ...

# It's important to fit the scaler only on the training data, not the test data.

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Applying Linear Regression Model</font>

# %%
Model = LinearRegression()
Model.fit(X_train_scaled, y_train)

# Calculating Details
print('Linear Regression Train Score is : ' , Model.score(X_train_scaled, y_train))
print('Linear Regression Test Score is : ' , Model.score(X_test_scaled, y_test))
print('Linear Regression Coef is : ' , Model.coef_)
print('Linear Regression intercept is : ' , Model.intercept_)

# Calculating Prediction
y_pred = Model.predict(X_test_scaled)
# Out:
# Linear Regression Train Score is :  0.9510015268301873
# Linear Regression Test Score is :  0.9403937677545078
# Linear Regression Coef is :  [132666.71872175 -10489.17656639  14051.72334156  -1233.23294938]
# Linear Regression intercept is :  51485.0521545796

# %%
y_predection = pd.DataFrame(data={'Predicted Profit ': y_pred.flatten()})
print(y_predection.head())
# Out:
#    Predicted Profit
# 0      126568.769413
# 1       86103.320655
# 2       98856.919704
# 3       45879.381899
# 4      127503.114500

# %%
print('Actual Profit')
y_test.head()
# Out:
# Actual Profit
# 13    134307.35
# 39     81005.76
# 30     99937.59
# 45     64926.08
# 17    125370.37
# Name: Profit, dtype: float64

# %%
Testing_Data_Model_score = Model.score(X_test_scaled, y_test)
print(f'Mode Score/Performance On Testing Data {Testing_Data_Model_score * 100:.2f}%')

Training_Data_Model_score = Model.score(X_train_scaled, y_train)
print(f'Mode Score/Performance On Training Data {Training_Data_Model_score * 100:.2f}%')
# Out:
# Mode Score/Performance On Testing Data 94.04%
# Mode Score/Performance On Training Data 95.10%

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Plotting the performance of the model</font>

# %%
# Model scores for each dataset
training_score = Training_Data_Model_score
testing_score = Testing_Data_Model_score

# Define datasets and corresponding scores
datasets = ['Training Data', 'Testing Data']
scores = [training_score, testing_score]

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(datasets, scores, color=['blue', 'green'])
plt.ylim(0, 1)  # Set y-axis limits to be between 0 and 1 for accuracy percentage
plt.ylabel('Accuracy')
plt.title('Model Performance on Training and Testing Data')

# Adding values on top of the bars
for i, score in enumerate(scores):
    plt.text(i, score, f'{score * 100:.2f}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ Evaluation the model</font>

# %%
# Calculating r2_score
r2_Score = r2_score(y_pred, y_test)
print('R2 Score Of Model is : ', r2_Score * 100)

# Calculating Mean Absolute Error
MAEValue = mean_absolute_error(y_pred, y_test)
print('Mean Absolute Error Value is : ', MAEValue * 100)

# Calculating Mean Squared Error
MSEValue = mean_squared_error(y_pred, y_test)
print('Mean Squared Error Value is : ', MSEValue * 100)
# Out:
# R2 Score Of Model is :  93.38388124691897
# Mean Absolute Error Value is :  737116.1531097542
# Mean Squared Error Value is :  8386602764.431877

# %% [markdown]
# # <font color='DarkSlateGrey'>⚑ y_test vs. y_pred</font>

# %%
plt.scatter(y_test, y_pred)
plt.show()
